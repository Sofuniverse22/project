# %%
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from datetime import datetime

# %%
from tqdm import tqdm_notebook
from selenium import webdriver
import time

# %%
url = 'https://coinmarketcap.com/coins/{}'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'html.parser')

# %%
base_url = 'https://coinmarketcap.com/coins/{}'
 

    
    page = urlopen(url)
    soup = BeautifulSoup(page, 'html.parser')
    table = soup.find('table')
    table_rows = table.find_all('tr')
    for tr in table_rows:
        td = tr.find_all('td')
        row = [i.text for i in td]
        print(row)
# Out:
# []
# ['\n1\n', '\n\nBTC\n\nBitcoin\n', '\n$71,526,760,106\n', '\n$4102.66\n', '\n$9,238,580,961\n', '\n\n17,434,225\nBTC\n\n', '4.87%', '\n\n', '\n\n\n\n\nAdd to Watchlist\nRemove from Watchlist\nWatchlist full!\nView Chart\nView Markets\nView Historical Data\n\n']
# ['\n2\n', '\n\nXRP\n\nXRP\n', '\n$15,246,180,783\n', '\n$0.374026\n', '\n$1,037,202,929\n', '\n\n40,762,365,544\nXRP\n\n*\n', '1.70%', '\n\n', '\n\n\n\n\nAdd to Watchlist\nRemove from Watchlist\nWatchlist full!\nView Chart\nView Markets\nView Historical Data\n\n']
# ['\n3\n', '\n\nETH\n\nEthereum\n', '\n$12,078,993,810\n', '\n$116.23\n', '\n$3,219,536,065\n', '\n\n103,921,521\nETH\n\n', '9.80%', '\n\n', '\n\n\n\n\nAdd to Watchlist\nRemove from Watchlist\nWatchlist full!\nView Chart\nView Markets\nView Historical Data\n\n']
# ...

# %%
table = soup.find('table')

# %%
table_rows = table.find_all('tr')

# %%
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['\n1\n', '\n\nBTC\n\nBitcoin\n', '\n$70,551,802,705\n', '\n$4046.75\n', '\n$9,231,340,812\n', '\n\n17,434,200\nBTC\n\n', '5.05%', '\n\n', '\n\n\n\n\nAdd to Watchlist\nRemove from Watchlist\nWatchlist full!\nView Chart\nView Markets\nView Historical Data\n\n']
# ['\n2\n', '\n\nXRP\n\nXRP\n', '\n$14,957,115,059\n', '\n$0.366934\n', '\n$1,035,928,288\n', '\n\n40,762,365,544\nXRP\n\n*\n', '1.46%', '\n\n', '\n\n\n\n\nAdd to Watchlist\nRemove from Watchlist\nWatchlist full!\nView Chart\nView Markets\nView Historical Data\n\n']
# ['\n3\n ', '\n\nETH\n\nEthereum\n', '\n$11,849,296,132\n', '\n$114.02\n', '\n$3,192,820,775\n', '\n\n103,920,975\nETH\n\n', '9.39%', '\n\n', '\n\n\n\n\nAdd to Watchlist\nRemove from Watchlist\nWatchlist full!\nView Chart\nView Markets\nView Historical Data\n\n']
# ...

# %%
dfs = pd.read_html('https://coinmarketcap.com/coins/',header=0)
for df in dfs:
    print(df)
# Out:
#       #                  Name       Market Cap      Price    Volume (24h)  \
# 0     1           BTC Bitcoin  $70,936,261,360   $4068.78  $8,747,732,850
# 1     2               XRP XRP  $15,117,102,933  $0.370859    $944,030,727
# 2     3          ETH Ethereum  $11,998,410,833    $115.46  $3,095,584,674
# 3     4      BCH Bitcoin Cash   $3,907,144,173    $222.98  $2,104,693,687
# 4     5           XLM Stellar   $2,421,087,228  $0.126430    $156,349,392
# 5     6               EOS EOS   $2,420,977,696      $2.67  $1,256,876,993
# 6     7        BSV Bitcoin SV   $2,223,873,465    $126.92    $683,789,642
# 7     8          LTC Litecoin   $1,895,957,718     $31.78    $748,690,172
# 8     9              TRX TRON   $1,293,209,004  $0.019410    $170,175,164
# 9    10           ADA Cardano   $1,093,751,419  $0.042186     $74,561,363
# 10   11            MIOTA IOTA     $978,117,507  $0.351900     $28,330,782
# 11   12            XMR Monero     $891,115,014     $53.48     $21,381,453
# ...

# %%
df =dfs[0]
df

# %%
#s=pd.Series(df['Name'])
#s2=s.str.split(" ")
  
# new data frame with split value columns 
new = df["Name"].str.split(" ", n = 1, expand = True) 
  
# making seperate first name column from new data frame 
df["abb"]= new[0] 
  
# making seperate last name column from new data frame 
df["name"]= new[1] 
  
# Dropping old Name columns 
df.drop(columns =["Name"], inplace = True) 
  
# df display 
df

# %%
df['name']

# %%
df['name'].to_csv('coinname.csv',encoding='utf-8')

# %%
df1 = pd.read_csv('coinname.csv') 
df2 = pd.read_csv('coinname2.csv')
df3 = pd.read_csv('coinname3.csv') 
df4 = pd.read_csv('coinname4.csv')
df5 = pd.read_csv('coinname5.csv') 
df6 = pd.read_csv('coinname6.csv')
df7 = pd.read_csv('coinname7.csv') 
df8 = pd.read_csv('coinname8.csv')
df9 = pd.read_csv('coinname9.csv')
merged_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], axis = 1, join = 'outer')

# %%
merged_df.to_csv('origin.csv', encoding='utf-8')

# %%
sf=pd.read_csv('origin2.csv')

# %%
df=sf["Name"]
df
# Out:
# 0               Bitcoin
# 1                   XRP
# 2              Ethereum
# 3          Bitcoin Cash
# 4                   EOS
# 5               Stellar
# 6            Bitcoin SV
# 7              Litecoin
# 8                  TRON
# 9               Cardano
# 10                 IOTA
# 11               Monero
# 12                 Dash
# 13                  NEM
# 14     Ethereum Classic
# 15                  NEO
# 16                Waves
# 17                Zcash
# 18             Dogecoin
# 19                Tezos
# 20         Bitcoin Gold
# 21              VeChain
# 22                 Qtum
# 23             Ontology
# 24                 Lisk
# 25               Decred
# 26      Bitcoin Diamond
# 27                 Nano
# 28             Bytecoin
# 29              Stratis
#              ...
# 844          CottonCoin
# 845       First Bitcoin
# 846            BetaCoin
# 847          Sakuracoin
# 848          CoffeeCoin
# 849           Labh Coin
# 850            Cropcoin
# ...

# %% [markdown]
# ### 코인의 name을 받아 url = 'https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20171220&end=20181220'  에 해당하는  url에 코인 name을 넣고 크롤링하면 될듯
