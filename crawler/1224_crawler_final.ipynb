# %%
import numpy as np
import pandas as pd
from datetime import datetime
from urllib.request import urlopen
from tqdm import tqdm_notebook
from selenium import webdriver
import time

# %%
url_base = 'https://coinmarketcap.com'
html = urlopen(url_base)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# ...

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# ...

# %%
list_soup = soup.find_all('td', 'no-wrap currency-name')
list_soup
# Out:
# [<td class="no-wrap currency-name" data-sort="Bitcoin">
#  <img alt="Bitcoin" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/16x16/1.png" width="16"/>
#  <span class="currency-symbol visible-xs"><a class="link-secondary" href="/currencies/bitcoin/">BTC</a></span>
#  <br class="visible-xs"/>
#  <a class="currency-name-container link-secondary" href="/currencies/bitcoin/">Bitcoin</a>
#  </td>, <td class="no-wrap currency-name" data-sort="XRP">
#  <img alt="XRP" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/16x16/52.png" width="16"/>
#  <span class="currency-symbol visible-xs"><a class="link-secondary" href="/currencies/ripple/">XRP</a></span>
#  <br class="visible-xs"/>
#  <a class="currency-name-container link-secondary" href="/currencies/ripple/">XRP</a>
#  </td>, <td class="no-wrap currency-name" data-sort="Ethereum">
# ...

# %%
len(soup.find_all('td', 'no-wrap currency-name'))
# Out:
# 100

# %%
print(soup.find_all('td', 'no-wrap currency-name')[0])
# Out:
# <td class="no-wrap currency-name" data-sort="Bitcoin">
# <img alt="Bitcoin" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/16x16/1.png" width="16"/>
# <span class="currency-symbol visible-xs"><a class="link-secondary" href="/currencies/bitcoin/">BTC</a></span>
# <br class="visible-xs"/>
# <a class="currency-name-container link-secondary" href="/currencies/bitcoin/">Bitcoin</a>
# </td>

# %%
tmp_one = soup.find_all('td', 'no-wrap currency-name')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_='logo')

# %%
tmp_one.find('a')['href']
# Out:
# '/currencies/bitcoin/'

# %%
import re

tmp_string

# %%
from urllib.parse import urljoin

url_add = []
list_soup = soup.find_all('td', 'no--wrap currency-name')

for coin in list_soup:
    url_add.append(urljoin(url_base, coin.find('a')['href']))

# %%
url_add
# Out:
# []
